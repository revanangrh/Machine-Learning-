# %% [markdown]
# <a href="https://colab.research.google.com/github/revanangrh/Machine-Learning-/blob/main/Copy_of_Tugas6_Regresi_Soal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Buat dataset sederhana
np.random.seed(0)
X = 2 * np.random.rand(100, 1)  # Fitur
y = 4 + 3 * X + np.random.randn(100, 1)  # Target (dengan sedikit noise)

# Plot dataset
plt.scatter(X, y)
plt.xlabel('Fitur')
plt.ylabel('Target')
plt.title('Dataset Sederhana untuk Latihan Regresi')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# Inisialisasi model regresi linear
model = LinearRegression()

# Latih model menggunakan data
model.fit(X, y)
y_pred = model.predict(X)
import numpy as np

# Evaluasi Regresi
r2 = r2_score(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y, y_pred)
mape = np.mean(np.abs((y - y_pred) / (y + 1e-10))) * 100

print("=== Evaluasi Regresi ===")
print("R2 Score:", r2)
print("MSE:", mse)
print("RMSE:", rmse)
print("MAE:", mae)
print("MAPE:", mape)

# Koefisien (slope) dan intersep dari model
slope = model.coef_[0][0]
intercept = model.intercept_[0]

print("Koefisien (slope):", slope)
print("Intersep:", intercept)

import matplotlib.pyplot as plt

plt.scatter(y, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.show()
# Out:
# === Evaluasi Regresi ===
# R2 Score: 0.7469629925504755
# MSE: 0.9924386487246479
# RMSE: 0.9962121504602561
# MAE: 0.8492581983239289
# MAPE: 13.42908835947403
# Koefisien (slope): 2.968467510701019
# Intersep: 4.222151077447231
